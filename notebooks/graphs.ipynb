# %%
import pandas as pd

t = pd.read_csv("mp20-results.csv")

# %%
t = t.fillna(' ')
t[t.status == ' ']
# Out:
#        Unnamed: 0 status material_id        time
# 2               2         mp-1209679    0.789871
# 3               3         mp-1020059    0.620733
# 4               4         mp-1189429    1.205847
# 5               5          mp-756309    2.557689
# 6               6         mp-1220565    1.129870
# ...           ...    ...         ...         ...
# 45146        3180         mp-1106031   66.960862
# 45150       15520          mp-677378   67.381793
# 45159        1538         mp-1228959   68.343451
# 45210       12602          mp-644506   77.162810
# 45228         512         mp-1215784  144.891749
#
# [38456 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

omat = 100 * 447303 / 451704
mp20 = 100 * 38456 / 45229

labels = ['omat', 'mp20']
values = [omat, mp20]

bars = plt.bar(labels, values, color=['#1f77b4', '#ff7f0e'])
plt.ylabel('Значение')
plt.title('Конверсия датасетов omat и mp20')
plt.legend(bars, labels)
plt.ylim(0, 100)
plt.show()

# %%
omat = 100 * 447303/ 451704
mp20 = 100 * 38456 / 45229
omat, mp20
# Out:
# (99.02568938951171, 85.02509451900329)
